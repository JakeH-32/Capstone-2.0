# %%
import dummyMain
import modelBuilder as mb
import pandas as pd
nextQ, questionDifficulty, distributions = dummyMain.initialize()
data = pd.read_csv("data.csv")
Qdata = data.iloc[1000:1010]
nextQ = "lsn1_helloworld"
qData = mb.convertRawtoClean(Qdata)
# Out:
# C:\Users\C22Evan.Marrone\Anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
mb.increaseDifficulty(nextQ, questionDifficulty)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-1a9021134b09> in <module>
# ----> 1 mb.increaseDifficulty(nextQ, questionDifficulty)
#
# ~\OneDrive - afacademy.af.edu\Desktop\Classes\Capstone\Cap 2.0\Capstone-2.0\Controller\modelBuilder.py in increaseDifficulty(lastQ_id, difficulty_values)
#     198         # look at all questions with lesser difficulty than the last completed Q
#     199         lowerBound = difficulty_values[difficulty_values['problem'] == lastQ_id].index[0]
# --> 200         greaterDiff = difficulty_values.iloc[lowerBound:len(difficulty_values)]
#     201         # choose a question that is a third of the way from the last Q difficulty to the easiest question difficulty
#     202         nextQ = greaterDiff.iloc[int(np.ceil(len(greaterDiff) * .33)) - 1].problem
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
lowerBound = questionDifficulty[questionDifficulty['problem'] == nextQ].index[0]
lowerBound
# Out:
# 57

# %%
questionDifficulty.iloc[lowerBound:len(questionDifficulty)]
# Out:
#                        problem  difficulty
# 57             lsn1_helloworld    0.043801
# 58            lsn6_bits_to_kmg    0.043830
# 59                  a1_1_dorms    0.044805
# 60               a2_1_equation    0.045637
# 61                a3_2_grammys    0.046963
# ..                         ...         ...
# 248                 lsn19_100m    0.647131
# 249            lsn24_education    0.659379
# 250         lsn15_titanicfares    0.672693
# 251  lsn15_survivors_by_gender    0.725330
# 252                 lsn24_nasa    0.742961
#
# [196 rows x 2 columns]

# %%
questionDifficulty[questionDifficulty["problem"]==nextQ]
# Out:
#             problem  difficulty
# 57  lsn1_helloworld    0.043801

# %%
lastQ_index = questionDifficulty[questionDifficulty['problem'] == 'a2_6_traffic_lights'].index[0]
questionDifficulty = questionDifficulty.drop([lastQ_index]).reset_index().drop(["index"], axis=1)

# %%
questionDifficulty
# Out:
#                        problem  difficulty
# 0                  lsn23_paint    0.000000
# 1              a1_4_goldilocks    0.000000
# 2               a1_4_satellite    0.000000
# 3                  a1_4_vspeed    0.000000
# 4                   a3_2_bands    0.000000
# ..                         ...         ...
# 247                 lsn19_100m    0.647131
# 248            lsn24_education    0.659379
# 249         lsn15_titanicfares    0.672693
# 250  lsn15_survivors_by_gender    0.725330
# 251                 lsn24_nasa    0.742961
#
# [252 rows x 2 columns]

# %%
questionDifficulty.loc[questionDifficulty.problem =='lsn7_lists']
# mb.maintainDifficulty('a1_7_sickness', questionDifficulty)
# Out:
#         problem  difficulty
# 283  lsn7_lists    0.207924

# %%
questionDifficulty
# Out:
#      Unnamed: 0                    problem  difficulty
# 0             0              a1_7_sickness    0.000000
# 1             1             a1_3_satellite    0.000000
# 2             2                lsn23_paint    0.000000
# 3             3               a3_2_excuses    0.000000
# 4             4            a1_4_goldilocks    0.000000
# ..          ...                        ...         ...
# 395         395  lsn15_survivors_by_gender    0.725330
# 396         396                 lsn24_nasa    0.742961
# 397         397                 Lsn7_lists    0.891572
# 398         398                 to_the_end    0.913582
# 399         399                       pex1    1.000000
#
# [400 rows x 3 columns]

# %%
mb.nextQuestion(problem, questionDifficulty, distributions, qData)
# Out:
# 'a2_4_pipe'

# %%
mb.maintainDifficulty(problem, questionDifficulty)
# Out:
# 'lsn5_calories'

# %%
upperBound = questionDifficulty[questionDifficulty['problem'] == 'a1_2_lessons'].index[0]
lesserDiff = questionDifficulty.iloc[0:upperBound].drop(["Unnamed: 0"], axis=1)

# %%
questionDifficulty.iloc[0:upperBound].drop(["Unnamed: 0"], axis=1)
# Out:
#                    problem  difficulty
# 0            a1_7_sickness         0.0
# 1           a1_3_satellite         0.0
# 2              lsn23_paint         0.0
# 3             a3_2_excuses         0.0
# 4          a1_4_goldilocks         0.0
# 5      lsn21_bouncingballs         0.0
# 6           a1_4_satellite         0.0
# 7              a1_4_vspeed         0.0
# 8           a4_5_password          0.0
# 9               a3_2_bands         0.0
# 10              a1_5_sound         0.0
# 11             lsn21_stamp         0.0
# 12                a1_7_dog         0.0
# 13          lsn21_triangle         0.0
# 14              a1_6_paint         0.0
# 15      lsn22_bouncingball         0.0
# 16     lsn22_bouncingballs         0.0
# 17        a1_7_pilot_quals         0.0
# 18        lsn23_soundboard         0.0
# 19  lsn22_bouncingtriangle         0.0

# %%
questionDifficulty
# Out:
#      Unnamed: 0                    problem  difficulty
# 0             0              a1_7_sickness    0.000000
# 1             1             a1_3_satellite    0.000000
# 2             2                lsn23_paint    0.000000
# 3             3               a3_2_excuses    0.000000
# 4             4            a1_4_goldilocks    0.000000
# ..          ...                        ...         ...
# 395         395  lsn15_survivors_by_gender    0.725330
# 396         396                 lsn24_nasa    0.742961
# 397         397                 Lsn7_lists    0.891572
# 398         398                 to_the_end    0.913582
# 399         399                       pex1    1.000000
#
# [400 rows x 3 columns]
