# %%
import os
import glob


file_list = glob.glob("C:\Users\C22Evan.Marrone\OneDrive - afacademy.af.edu\Desktop\Classes\Capstone\Cap 2.0\Capstone-2.0\Labs\*")
print(file_list)
# Out:
#   File "<ipython-input-3-eba0a3069614>", line 5
#     file_list = glob.glob("C:\Users\C22Evan.Marrone\OneDrive - afacademy.af.edu\Desktop\Classes\Capstone\Cap 2.0\Capstone-2.0\Labs\*")
#                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
file_list = os.listdir("C:/Users/C22Evan.Marrone/OneDrive - afacademy.af.edu/Desktop/Classes/Capstone/Cap 2.0/Capstone-2.0/Labs/")

# %%
files = []
for file in file_list:
    if file[-3:]==".py":
        file = file[0:-3]
        files.append(file)

# %%
files
# Out:
# ['DataStructures_crashes',
#  'DataStructures_crashes_test',
#  'DataStructures_tokens',
#  'DataStructures_tokens_test',
#  'FileIO_echo',
#  'FileIO_echo_test',
#  'FileIO_runways',
#  'FileIO_runways_test',
#  'FileIO_survivors_by_gender',
#  'FileIO_survivors_by_gender_test',
#  'FileIO_titanicfares',
#  'FileIO_titanicfares_test',
#  'FileIO_titanicsurvivor',
#  'FileIO_titanicsurvivor_test',
#  'Graphics2_bouncingball',
#  'Graphics2_bouncingballs_test',
#  'Graphics2_bouncingball_test',
#  'Graphics2_bouncingtriangle',
#  'Graphics2_bouncingtriangle_test',
#  'Graphics3_bouncingballs_test',
#  'Graphics3_paint',
#  'Graphics3_paint_test',
#  'Graphics3_soundboard',
#  'Graphics3_soundboard_test',
#  'IterLogic1_averagerun',
#  'IterLogic1_averagerun_test',
#  'IterLogic1_cargocapacity',
#  'IterLogic1_cargocapacity_test',
#  'IterLogic1_count',
#  'IterLogic1_countby10s',
#  'IterLogic1_countby10s_test',
#  'IterLogic1_count_test',
#  'IterLogic1_dvc',
# ...

# %%
import pandas as pd
needed_qs = pd.read_csv("questions.csv")

# %%
needed_qs
# Out:
#             problem
# 0     a1_1_aircraft
# 1        a1_1_bases
# 2        a1_1_cadet
# 3        a1_1_dorms
# 4         a1_1_icbm
# ..              ...
# 248        lsn8_uod
# 249  lsn9_practice1
# 250  lsn9_practice2
# 251  lsn9_practice3
# 252  lsn9_practice4
#
# [253 rows x 1 columns]

# %%
needed_qs[needed_qs.problem.isin(files)]
# Out:
#              problem
# 123     lsn11_skill1
# 124     lsn11_skill2
# 131     lsn12_skill1
# 132     lsn12_skill2
# 138     lsn13_skill1
# 139     lsn13_skill2
# 147     lsn14_skill1
# 148     lsn14_skill2
# 165     lsn18_skill1
# 166     lsn18_skill2
# 173     lsn19_skill1
# 175  lsn1_helloworld
# 180     lsn20_skill1
# 184     lsn21_skill1
# 225      lsn5_skill1
# 226      lsn5_skill2
# 233      lsn6_skill1
# 234      lsn6_skill2
# 240      lsn7_skill1

# %%
files
# Out:
# ['DataStructures_crashes',
#  'DataStructures_crashes_test',
#  'DataStructures_tokens',
#  'DataStructures_tokens_test',
#  'FileIO_echo',
#  'FileIO_echo_test',
#  'FileIO_runways',
#  'FileIO_runways_test',
#  'FileIO_survivors_by_gender',
#  'FileIO_survivors_by_gender_test',
#  'FileIO_titanicfares',
#  'FileIO_titanicfares_test',
#  'FileIO_titanicsurvivor',
#  'FileIO_titanicsurvivor_test',
#  'Graphics2_bouncingball',
#  'Graphics2_bouncingballs_test',
#  'Graphics2_bouncingball_test',
#  'Graphics2_bouncingtriangle',
#  'Graphics2_bouncingtriangle_test',
#  'Graphics3_bouncingballs_test',
#  'Graphics3_paint',
#  'Graphics3_paint_test',
#  'Graphics3_soundboard',
#  'Graphics3_soundboard_test',
#  'IterLogic1_averagerun',
#  'IterLogic1_averagerun_test',
#  'IterLogic1_cargocapacity',
#  'IterLogic1_cargocapacity_test',
#  'IterLogic1_count',
#  'IterLogic1_countby10s',
#  'IterLogic1_countby10s_test',
#  'IterLogic1_count_test',
#  'IterLogic1_dvc',
# ...

# %%
needed_qs
# Out:
#             problem
# 0     a1_1_aircraft
# 1        a1_1_bases
# 2        a1_1_cadet
# 3        a1_1_dorms
# 4         a1_1_icbm
# ..              ...
# 248        lsn8_uod
# 249  lsn9_practice1
# 250  lsn9_practice2
# 251  lsn9_practice3
# 252  lsn9_practice4
#
# [253 rows x 1 columns]
